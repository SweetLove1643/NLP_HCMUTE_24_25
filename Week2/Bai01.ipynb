# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://playground.roborabbit.com/jobs/'
response = requests.get(url)

html = response.content

soup = BeautifulSoup(html , 'html.parser')

job_listings = soup.find_all(class_='job card')
titles=[]
links=[]
names=[]
salarys=[]
locations=[]

for job_listing in job_listings:
    job_title = job_listing.find('a').text
    job_link = job_listing.find('a')['href']
    company_name = job_listing.find(class_ = 'company').text
    salary =job_listing.find(class_ = 'salary').text
    location = job_listing.find(class_ = 'location').text

    titles.append(job_title)
    links.append(job_link)
    names.append(company_name)
    salarys.append(salary)
    locations.append(location)

    print(f"Job Title: {job_title}")
    print(f"Job Link: {job_link}")
    print(f"Company name: {company_name}")
    print(f"Salary : {salary}")
    print(f"Location : {location}")
    print("\n")
    
dic = {"title": titles, "links": links, 'name':names, 'salary': salarys, 'location':locations}
df = pd.DataFrame(dic)
print(df.head(25))
# Out:
# Job Title: Senior Community-Services Administrator
# Job Link: /jobs/__5qLx3OctM-senior-community-services-administrator/
# Company name: Toughjoyfax Inc
# Salary : $13,000 / year
# Location : Faroe Islands
#
#
# Job Title: Principal Design Agent
# Job Link: /jobs/Ainsa9pynZg-principal-design-agent/
# Company name: Cheetah Group
# Salary : $19,000 / year
# Location : Liechtenstein
#
#
# Job Title: Internal Hospitality Director
# Job Link: /jobs/Pi36OJrcDVc-internal-hospitality-director/
# Company name: Kanlam and Sons
# Salary : $147,000 / year
# Location : Singapore
#
#
# Job Title: Central Director
# Job Link: /jobs/a-oQet9OWpk-central-director/
# Company name: Prodder LLC
# Salary : $16,000 / year
# Location : Antarctica (the territory South of 60 deg S)
#
#
# Job Title: Retail Liaison
# Job Link: /jobs/2-FrYyvyYqk-retail-liaison/
# Company name: Oyster and Sons
# Salary : $15,000 / year
# Location : Sao Tome and Principe
#
#
# Job Title: Global Manufacturing Technician
# Job Link: /jobs/jFv-wpSoi_s-global-manufacturing-technician/
# Company name: Wasp Inc
# Salary : $18,000 / year
# Location : Gabon
#
#
# Job Title: Design Liaison
# Job Link: /jobs/xGOmJWSQc1k-design-liaison/
# Company name: Span LLC
# Salary : $11,000 / year
# Location : Netherlands Antilles
#
#
# Job Title: Legacy Education Administrator
# Job Link: /jobs/7OX0oyl0F9g-legacy-education-administrator/
# Company name: Tempsoft LLC
# Salary : $11,000 / year
# Location : Slovenia
#
#
# Job Title: Education Administrator
# Job Link: /jobs/cMi9kVFGEUE-education-administrator/
# Company name: Treeflex and Sons
# Salary : $12,000 / year
# Location : United Arab Emirates
#
#
# Job Title: Farming Consultant
# Job Link: /jobs/vcT80C8lD-4-farming-consultant/
# Company name: Lotlux Inc
# Salary : $18,000 / year
# Location : Jordan
#
#
# Job Title: Investor Coordinator
# Job Link: /jobs/HyDt0GAUzwM-investor-coordinator/
# Company name: Tres Zap and Sons
# Salary : $19,000 / year
# Location : United States of America
#
#
# Job Title: Consulting Liaison
# Job Link: /jobs/zWfTdZRIuUw-consulting-liaison/
# Company name: Greenlam LLC
# Salary : $133,000 / year
# Location : Niue
#
#
# Job Title: Corporate IT Administrator
# Job Link: /jobs/eJSHJ1e-6CM-corporate-it-administrator/
# Company name: Cardify and Sons
# Salary : $12,000 / year
# Location : Iceland
#
#
# Job Title: Design Officer
# Job Link: /jobs/y_FclEnivOM-design-officer/
# Company name: Gnu Inc
# Salary : $91,000 / year
# Location : Uganda
#
#
# Job Title: Hospitality Analyst
# Job Link: /jobs/mI8v2pEOo8E-hospitality-analyst/
# Company name: Llama Group
# Salary : $59,000 / year
# Location : Tuvalu
#
#
# Job Title: Community-Services Facilitator
# Job Link: /jobs/brOBI7tj_v4-community-services-facilitator/
# Company name: Clam and Sons
# Salary : $83,000 / year
# Location : Ethiopia
#
#
# Job Title: Central Consultant
# Job Link: /jobs/250H49_317E-central-consultant/
# Company name: Wrapsafe LLC
# Salary : $16,000 / year
# Location : Virgin Islands, U.S.
#
#
# Job Title: Mining Assistant
# Job Link: /jobs/vuYqzyHEbFg-mining-assistant/
# Company name: Namfix LLC
# Salary : $18,000 / year
# Location : Mauritius
#
#
# Job Title: Corporate Mining Architect
# Job Link: /jobs/j_zfrCBFR_E-corporate-mining-architect/
# Company name: Alphazap LLC
# Salary : $16,000 / year
# Location : Serbia
#
#
# Job Title: Product Consultant
# Job Link: /jobs/uTQ14QEacE4-product-consultant/
# Company name: Flowdesk Group
# Salary : $102,000 / year
# Location : Saint Kitts and Nevis
#
#
# Job Title: Hospitality Representative
# Job Link: /jobs/g5BB5Wm9MDE-hospitality-representative/
# Company name: Dolphin Inc
# Salary : $11,000 / year
# Location : Cook Islands
#
#
# Job Title: Central Analyst
# Job Link: /jobs/U2_o2nTv6yc-central-analyst/
# Company name: Y Solowarm and Sons
# Salary : $126,000 / year
# Location : Kyrgyz Republic
#
#
# Job Title: Internal Education Technician
# Job Link: /jobs/qRRcnWuoedU-internal-education-technician/
# Company name: Louse LLC
# Salary : $105,000 / year
# Location : Liberia
#
#
# Job Title: Global Sales Analyst
# Job Link: /jobs/_JDDcfZlPCs-global-sales-analyst/
# Company name: Asoka Group
# Salary : $12,000 / year
# Location : Saudi Arabia
#
#
# Job Title: Forward Manager
# Job Link: /jobs/x5l8ZuWh-ls-forward-manager/
# Company name: Cicada Inc
# Salary : $41,000 / year
# Location : Mauritania
#
#
# Job Title: Government Representative
# Job Link: /jobs/ZjvGxoJGjX4-government-representative/
# Company name: Sea Lion and Sons
# Salary : $132,000 / year
# Location : Romania
#
#
# Job Title: Dynamic IT Administrator
# Job Link: /jobs/w9dxz2RYrqs-dynamic-it-administrator/
# Company name: Home Ing Inc
# Salary : $14,000 / year
# Location : Tokelau
#
#
# Job Title: Community-Services Associate
# Job Link: /jobs/EsEusi2Bisw-community-services-associate/
# Company name: Wildebeest Group
# Salary : $65,000 / year
# Location : New Caledonia
#
#
# Job Title: Product Community-Services Assistant
# Job Link: /jobs/JdlXSytj2vk-product-community-services-assistant/
# Company name: Zathin Inc
# Salary : $88,000 / year
# Location : El Salvador
#
#
# Job Title: Marketing Designer
# Job Link: /jobs/NMiCJS3hwNE-marketing-designer/
# Company name: Sheep and Sons
# Salary : $94,000 / year
# Location : Trinidad and Tobago
#
#
# Job Title: Investor Architect
# Job Link: /jobs/iZoUrjPgUoY-investor-architect/
# Company name: Horse Inc
# Salary : $14,000 / year
# Location : Saint Pierre and Miquelon
#
#
# Job Title: Lead Advertising Coordinator
# Job Link: /jobs/mA6AvsNcMqo-lead-advertising-coordinator/
# Company name: Bee Group
# Salary : $18,000 / year
# Location : Burundi
#
#
# Job Title: Education Executive
# Job Link: /jobs/fgX6YJjDUhU-education-executive/
# Company name: Ox Inc
# Salary : $11,000 / year
# Location : Isle of Man
#
#
# Job Title: Customer Community-Services Planner
# Job Link: /jobs/4_79ata6raw-customer-community-services-planner/
# Company name: Serval Inc
# Salary : $54,000 / year
# Location : Antigua and Barbuda
#
#
# Job Title: Lead Agent
# Job Link: /jobs/_p7pDOIK1ZY-lead-agent/
# Company name: Elk and Sons
# Salary : $17,000 / year
# Location : Jordan
#
#
# Job Title: Construction Designer
# Job Link: /jobs/C2qPq5LtS5c-construction-designer/
# Company name: Matsoft Group
# Salary : $19,000 / year
# Location : Martinique
#
#
# Job Title: District Community-Services Developer
# Job Link: /jobs/-Cmw4sxh1k8-district-community-services-developer/
# Company name: Chimpanzee Inc
# Salary : $32,000 / year
# Location : Indonesia
#
#
# Job Title: National Agent
# Job Link: /jobs/TyVf0SbtbG0-national-agent/
# Company name: Stronghold and Sons
# Salary : $103,000 / year
# Location : Albania
#
#
# Job Title: District Administrator
# Job Link: /jobs/TzT22HsHfis-district-administrator/
# Company name: Sheep LLC
# Salary : $10,000 / year
# Location : Cocos (Keeling) Islands
#
#
# Job Title: International Facilitator
# Job Link: /jobs/RFSM2s00rIM-international-facilitator/
# Company name: Cicada Group
# Salary : $10,000 / year
# Location : Turkey
#
#
# Job Title: Senior Banking Associate
# Job Link: /jobs/RApb9prKuu0-senior-banking-associate/
# Company name: Butterfly Inc
# Salary : $136,000 / year
# Location : Sudan
#
#
# Job Title: Accounting Executive
# Job Link: /jobs/6nyPYHpSMlM-accounting-executive/
# Company name: Y Solowarm and Sons
# Salary : $120,000 / year
# Location : Ecuador
#
#
# Job Title: Legacy Director
# Job Link: /jobs/vvjlhAvu2CA-legacy-director/
# Company name: Zebra and Sons
# Salary : $136,000 / year
# Location : France
#
#
# Job Title: Legal Director
# Job Link: /jobs/YxTjpTWDXWU-legal-director/
# Company name: Minnow and Sons
# Salary : $49,000 / year
# Location : French Southern Territories
#
#
# Job Title: Forward Consultant
# Job Link: /jobs/Wwd54aeW7Jg-forward-consultant/
# Company name: Ferret and Sons
# Salary : $116,000 / year
# Location : Estonia
#
#
# Job Title: Corporate Accounting Specialist
# Job Link: /jobs/ROTIL_bvrtU-corporate-accounting-specialist/
# Company name: Wombat Inc
# Salary : $14,000 / year
# Location : Czech Republic
#
#
# Job Title: Senior Marketing Administrator
# Job Link: /jobs/qDiRNlk7Hvk-senior-marketing-administrator/
# Company name: Butterfly and Sons
# Salary : $18,000 / year
# Location : Northern Mariana Islands
#
#
# Job Title: Accounting Engineer
# Job Link: /jobs/ooWYMEfr3z4-accounting-engineer/
# Company name: Herring Group
# Salary : $16,000 / year
# Location : Saint Martin
#
#
# Job Title: Real-Estate Director
# Job Link: /jobs/6LKA62ROYdI-real-estate-director/
# Company name: Antelope LLC
# Salary : $60,000 / year
# Location : Central African Republic
#
#
# Job Title: Government Manager
# Job Link: /jobs/w_0TdloV5VU-government-manager/
# Company name: Dog and Sons
# Salary : $119,000 / year
# Location : Colombia
#
#
# Job Title: Principal Farming Associate
# Job Link: /jobs/90deU2EWg3Y-principal-farming-associate/
# Company name: Zaam Dox LLC
# Salary : $118,000 / year
# Location : Mali
#
#
# Job Title: Accounting Developer
# Job Link: /jobs/G4NBnofFz1Y-accounting-developer/
# Company name: Transcof Group
# Salary : $112,000 / year
# Location : Saint Helena
#
#
# Job Title: Chief Banking Architect
# Job Link: /jobs/kC0z-1Vl9Ms-chief-banking-architect/
# Company name: Squirrel and Sons
# Salary : $136,000 / year
# Location : Madagascar
#
#
# Job Title: Hospitality Architect
# Job Link: /jobs/1Gj25N5b76k-hospitality-architect/
# Company name: Fix San and Sons
# Salary : $93,000 / year
# Location : Mauritania
#
#
# Job Title: Advertising Designer
# Job Link: /jobs/mKAcpXLAokU-advertising-designer/
# Company name: Hyena LLC
# Salary : $85,000 / year
# Location : Malawi
#
#
# Job Title: Customer Legal Supervisor
# Job Link: /jobs/nUdAH1oHxv4-customer-legal-supervisor/
# Company name: Badger Inc
# Salary : $102,000 / year
# Location : Jersey
#
#
# Job Title: Central IT Liaison
# Job Link: /jobs/aajw22TLacc-central-it-liaison/
# Company name: Moose LLC
# Salary : $19,000 / year
# Location : Mali
#
#
# Job Title: Administration Architect
# Job Link: /jobs/hwrAWsbzO4E-administration-architect/
# Company name: Sheep Inc
# Salary : $68,000 / year
# Location : Germany
#
#
# Job Title: Regional Coordinator
# Job Link: /jobs/Frb3ANFeSKo-regional-coordinator/
# Company name: Holdlamis and Sons
# Salary : $132,000 / year
# Location : Croatia
#
#
# Job Title: Marketing Representative
# Job Link: /jobs/Ok3EKAX-ktY-marketing-representative/
# Company name: Lizard LLC
# Salary : $72,000 / year
# Location : Macedonia
#
#
# Job Title: Dynamic Agent
# Job Link: /jobs/kqer54AJ5RU-dynamic-agent/
# Company name: Grasshopper Group
# Salary : $13,000 / year
# Location : Equatorial Guinea
#
#
# Job Title: Human Design Producer
# Job Link: /jobs/zGy3LSZN2vQ-human-design-producer/
# Company name: Coyote Inc
# Salary : $18,000 / year
# Location : Guyana
#
#
# Job Title: Consulting Executive
# Job Link: /jobs/GBjpfhn-d4g-consulting-executive/
# Company name: Gembucket Inc
# Salary : $17,000 / year
# Location : Brunei Darussalam
#
#
# Job Title: Education Analyst
# Job Link: /jobs/C17zozFlppA-education-analyst/
# Company name: Tempsoft Inc
# Salary : $44,000 / year
# Location : Cote d'Ivoire
#
#
# Job Title: Central Director
# Job Link: /jobs/XnAPuoPVFpU-central-director/
# Company name: Zaam Dox Group
# Salary : $10,000 / year
# Location : Turkey
#
#
# Job Title: Accounting Associate
# Job Link: /jobs/8fKKlOp7mbs-accounting-associate/
# Company name: Fish Inc
# Salary : $82,000 / year
# Location : Tajikistan
#
#
# Job Title: Central Assistant
# Job Link: /jobs/v6dbuc8OaQE-central-assistant/
# Company name: Temp LLC
# Salary : $78,000 / year
# Location : Martinique
#
#
# Job Title: Manufacturing Administrator
# Job Link: /jobs/FWxWBlJ2DPk-manufacturing-administrator/
# Company name: Beaver LLC
# Salary : $14,000 / year
# Location : Syrian Arab Republic
#
#
# Job Title: Regional Marketing Associate
# Job Link: /jobs/y7YxdpLuAwo-regional-marketing-associate/
# Company name: Beetle Group
# Salary : $15,000 / year
# Location : Tokelau
#
#
# Job Title: Consulting Administrator
# Job Link: /jobs/6EWEZ7EZScU-consulting-administrator/
# Company name: Wombat and Sons
# Salary : $19,000 / year
# Location : Hong Kong
#
#
# Job Title: Administration Associate
# Job Link: /jobs/emR9Xshk6VY-administration-associate/
# Company name: Greenlam Inc
# Salary : $89,000 / year
# Location : Tonga
#
#
# Job Title: Marketing Orchestrator
# Job Link: /jobs/eVm34eEgNFE-marketing-orchestrator/
# Company name: Gembucket Group
# Salary : $11,000 / year
# Location : Sri Lanka
#
#
# Job Title: Marketing Analyst
# Job Link: /jobs/JvwuIaNk_YA-marketing-analyst/
# Company name: Tresom Group
# Salary : $149,000 / year
# Location : Argentina
#
#
# Job Title: Retail Planner
# Job Link: /jobs/7XdH4f-AtLM-retail-planner/
# Company name: Rank and Sons
# Salary : $15,000 / year
# Location : Mauritius
#
#
# Job Title: Banking Orchestrator
# Job Link: /jobs/BrBYJ8s8wuQ-banking-orchestrator/
# Company name: Greenlam Group
# Salary : $141,000 / year
# Location : Pitcairn Islands
#
#
# Job Title: Community-Services Facilitator
# Job Link: /jobs/tyeSulkhoW8-community-services-facilitator/
# Company name: Job Group
# Salary : $15,000 / year
# Location : Lesotho
#
#
# Job Title: Government Executive
# Job Link: /jobs/yUlrEA6yWLA-government-executive/
# Company name: Prodder and Sons
# Salary : $10,000 / year
# Location : Comoros
#
#
# Job Title: Community-Services Facilitator
# Job Link: /jobs/80MZHJ24tYs-community-services-facilitator/
# Company name: Dinosaur Inc
# Salary : $85,000 / year
# Location : Djibouti
#
#
# Job Title: Design Strategist
# Job Link: /jobs/c3UatcBE1QM-design-strategist/
# Company name: Bytecard LLC
# Salary : $11,000 / year
# Location : Argentina
#
#
# Job Title: Global Producer
# Job Link: /jobs/gHh_LHek0io-global-producer/
# Company name: Bytecard LLC
# Salary : $135,000 / year
# Location : Cayman Islands
#
#
# Job Title: Government Architect
# Job Link: /jobs/DXdwUbqp97c-government-architect/
# Company name: Stronghold Inc
# Salary : $11,000 / year
# Location : Bhutan
#
#
# Job Title: International Education Producer
# Job Link: /jobs/XOHGLv7flpU-international-education-producer/
# Company name: Job Group
# Salary : $96,000 / year
# Location : Cameroon
#
#
# Job Title: Retail Executive
# Job Link: /jobs/Z3dpvHcYkJM-retail-executive/
# Company name: Flexidy Group
# Salary : $10,000 / year
# Location : Moldova
#
#
# Job Title: Chief Manager
# Job Link: /jobs/j7TMjxGuyv4-chief-manager/
# Company name: Zathin Inc
# Salary : $17,000 / year
# Location : Lithuania
#
#
# Job Title: Direct Liaison
# Job Link: /jobs/dFx4KjDp43g-direct-liaison/
# Company name: Andalax Inc
# Salary : $16,000 / year
# Location : Mozambique
#
#
# Job Title: Healthcare Executive
# Job Link: /jobs/p_nxHyf5gvI-healthcare-executive/
# Company name: Trout and Sons
# Salary : $17,000 / year
# Location : French Polynesia
#
#
# Job Title: Corporate Design Designer
# Job Link: /jobs/77l8XDwJhbs-corporate-design-designer/
# Company name: Sonair LLC
# Salary : $18,000 / year
# Location : Ghana
#
#
# Job Title: National Retail Consultant
# Job Link: /jobs/hOu3xRV9sAI-national-retail-consultant/
# Company name: Jellyfish Inc
# Salary : $77,000 / year
# Location : Colombia
#
#
# Job Title: Hospitality Architect
# Job Link: /jobs/sJqcU1SdDUk-hospitality-architect/
# Company name: Grasshopper and Sons
# Salary : $71,000 / year
# Location : Zimbabwe
#
#
# Job Title: Corporate Technology Consultant
# Job Link: /jobs/kwRxVo6Sr5I-corporate-technology-consultant/
# Company name: Fish Group
# Salary : $18,000 / year
# Location : Liechtenstein
#
#
# Job Title: Dynamic Education Technician
# Job Link: /jobs/CcuTAiYndDk-dynamic-education-technician/
# Company name: Mat Lam Tam and Sons
# Salary : $15,000 / year
# Location : Iceland
#
#
# Job Title: Internal Accounting Consultant
# Job Link: /jobs/l7wkvVpaeSg-internal-accounting-consultant/
# Company name: Bigtax Inc
# Salary : $15,000 / year
# Location : Vietnam
#
#
# Job Title: Internal Real-Estate Administrator
# Job Link: /jobs/e0SiwZ21kec-internal-real-estate-administrator/
# Company name: Skunk Inc
# Salary : $76,000 / year
# Location : Iraq
#
#
# Job Title: Technology Representative
# Job Link: /jobs/mU6Qg9OEJJY-technology-representative/
# Company name: Raven Inc
# Salary : $137,000 / year
# Location : Saint Vincent and the Grenadines
#
#
# Job Title: Dynamic Mining Designer
# Job Link: /jobs/7A_7bWBqxvw-dynamic-mining-designer/
# Company name: Serval LLC
# Salary : $12,000 / year
# Location : Macedonia
#
#
# Job Title: Forward Construction Director
# Job Link: /jobs/3_sC91qo81c-forward-construction-director/
# Company name: Bamity Group
# Salary : $95,000 / year
# Location : Portugal
#
#
# Job Title: Healthcare Technician
# Job Link: /jobs/KNYQZeTRuOc-healthcare-technician/
# Company name: Regrant and Sons
# Salary : $38,000 / year
# Location : Albania
#
#
# Job Title: Direct Banking Facilitator
# Job Link: /jobs/3xNuBkBjTbU-direct-banking-facilitator/
# Company name: Tresom LLC
# Salary : $16,000 / year
# Location : Portugal
#
#
# Job Title: Human Healthcare Analyst
# Job Link: /jobs/HvP7aENB7ro-human-healthcare-analyst/
# Company name: Otcom Inc
# Salary : $103,000 / year
# Location : Azerbaijan
#
#
# Job Title: Regional Legal Executive
# Job Link: /jobs/BsiICmiDX2w-regional-legal-executive/
# Company name: Hyena and Sons
# Salary : $121,000 / year
# Location : Madagascar
#
#
#                                       title  \
# 0   Senior Community-Services Administrator
# 1                    Principal Design Agent
# 2             Internal Hospitality Director
# 3                          Central Director
# 4                            Retail Liaison
# 5           Global Manufacturing Technician
# 6                            Design Liaison
# 7            Legacy Education Administrator
# 8                   Education Administrator
# 9                        Farming Consultant
# 10                     Investor Coordinator
# 11                       Consulting Liaison
# 12               Corporate IT Administrator
# 13                           Design Officer
# 14                      Hospitality Analyst
# 15           Community-Services Facilitator
# 16                       Central Consultant
# 17                         Mining Assistant
# 18               Corporate Mining Architect
# 19                       Product Consultant
# 20               Hospitality Representative
# 21                          Central Analyst
# 22            Internal Education Technician
# 23                     Global Sales Analyst
# 24                          Forward Manager
#
#                                                 links                 name  \
# 0   /jobs/__5qLx3OctM-senior-community-services-ad...      Toughjoyfax Inc
# 1           /jobs/Ainsa9pynZg-principal-design-agent/        Cheetah Group
# 2    /jobs/Pi36OJrcDVc-internal-hospitality-director/      Kanlam and Sons
# 3                 /jobs/a-oQet9OWpk-central-director/          Prodder LLC
# 4                   /jobs/2-FrYyvyYqk-retail-liaison/      Oyster and Sons
# 5   /jobs/jFv-wpSoi_s-global-manufacturing-technic...             Wasp Inc
# 6                   /jobs/xGOmJWSQc1k-design-liaison/             Span LLC
# 7   /jobs/7OX0oyl0F9g-legacy-education-administrator/         Tempsoft LLC
# 8          /jobs/cMi9kVFGEUE-education-administrator/    Treeflex and Sons
# 9               /jobs/vcT80C8lD-4-farming-consultant/           Lotlux Inc
# 10            /jobs/HyDt0GAUzwM-investor-coordinator/    Tres Zap and Sons
# 11              /jobs/zWfTdZRIuUw-consulting-liaison/         Greenlam LLC
# 12      /jobs/eJSHJ1e-6CM-corporate-it-administrator/     Cardify and Sons
# 13                  /jobs/y_FclEnivOM-design-officer/              Gnu Inc
# 14             /jobs/mI8v2pEOo8E-hospitality-analyst/          Llama Group
# 15  /jobs/brOBI7tj_v4-community-services-facilitator/        Clam and Sons
# 16              /jobs/250H49_317E-central-consultant/         Wrapsafe LLC
# 17                /jobs/vuYqzyHEbFg-mining-assistant/           Namfix LLC
# 18      /jobs/j_zfrCBFR_E-corporate-mining-architect/         Alphazap LLC
# 19              /jobs/uTQ14QEacE4-product-consultant/       Flowdesk Group
# 20      /jobs/g5BB5Wm9MDE-hospitality-representative/          Dolphin Inc
# 21                 /jobs/U2_o2nTv6yc-central-analyst/  Y Solowarm and Sons
# 22   /jobs/qRRcnWuoedU-internal-education-technician/            Louse LLC
# 23            /jobs/_JDDcfZlPCs-global-sales-analyst/          Asoka Group
# 24                 /jobs/x5l8ZuWh-ls-forward-manager/           Cicada Inc
#
#              salary                                      location
# 0    $13,000 / year                                 Faroe Islands
# 1    $19,000 / year                                 Liechtenstein
# 2   $147,000 / year                                     Singapore
# 3    $16,000 / year  Antarctica (the territory South of 60 deg S)
# 4    $15,000 / year                         Sao Tome and Principe
# 5    $18,000 / year                                         Gabon
# 6    $11,000 / year                          Netherlands Antilles
# 7    $11,000 / year                                      Slovenia
# 8    $12,000 / year                          United Arab Emirates
# 9    $18,000 / year                                        Jordan
# 10   $19,000 / year                      United States of America
# 11  $133,000 / year                                          Niue
# 12   $12,000 / year                                       Iceland
# 13   $91,000 / year                                        Uganda
# 14   $59,000 / year                                        Tuvalu
# 15   $83,000 / year                                      Ethiopia
# 16   $16,000 / year                          Virgin Islands, U.S.
# 17   $18,000 / year                                     Mauritius
# 18   $16,000 / year                                        Serbia
# 19  $102,000 / year                         Saint Kitts and Nevis
# 20   $11,000 / year                                  Cook Islands
# 21  $126,000 / year                               Kyrgyz Republic
# 22  $105,000 / year                                       Liberia
# 23   $12,000 / year                                  Saudi Arabia
# 24   $41,000 / year                                    Mauritania
